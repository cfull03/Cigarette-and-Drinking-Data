# %%
# Cell 1 — EDA bootstrap & imports (project-aware)

import sys
from pathlib import Path

ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents] if (p / "pyproject.toml").exists() or (p / ".git").exists()), Path.cwd())
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from addiction.utilities.config import load_config 

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 160)
plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["figure.dpi"] = 150

# Jupyter magic for inline plots
# %matplotlib inline

# %%
CSV_OVERRIDE = None
CFG = load_config(ROOT / "config" / "config.yaml")
csv_path = Path(CSV_OVERRIDE) if CSV_OVERRIDE else CFG.paths.raw_csv
assert csv_path.exists(), f"CSV not found: {csv_path}"

# Read CSV (fallback encoding if needed)
read_kwargs = dict(low_memory=False)
try:
    df = pd.read_csv(csv_path, **read_kwargs)
except UnicodeDecodeError:
    df = pd.read_csv(csv_path, encoding="latin-1", **read_kwargs)

rows, cols = df.shape
mem_mb = round(df.memory_usage(deep=True).sum() / (1024**2), 3)
print(f"Shape: {rows:,} × {cols:,} | Memory: {mem_mb} MB")
df.head(10)
# Out:
# Loaded: /Users/christianfullerton/Desktop/Coding Workspace/Python Workspace/Full Projects/Cigarette-and-Drinking-Data/data/raw/addiction_population_data.csv
# Shape: 3,000 × 25 | Memory: 2.184 MB
#    id              name  age  gender                country             city education_level employment_status  annual_income_usd     marital_status  \
# 0   1     Michael Bates   66   Other                  Yemen      Martinmouth       Secondary           Student              45595            Married
# 1   2    Brian Thompson   29    Male           Saudi Arabia      Harperhaven         Primary     Self-Employed             145842             Single
# 2   3     Steven Little   75    Male                   Togo         Chanport    Postgraduate        Unemployed             162480             Single
# 3   4   Michael Mathews   35   Other                   Togo       North Cory      University        Unemployed              16023  In a relationship
# 4   5  Nicholas Sanchez   38  Female                Morocco       Danielberg         College     Self-Employed              62933  In a relationship
# 5   6    Carrie Sellers   17    Male                Belgium      West Arthur       Secondary          Employed             178640             Single
# 6   7  Jessica Riley MD   36    Male  Saint Kitts and Nevis  Christopherstad         College     Self-Employed              20491            Widowed
# 7   8    Walter Tran MD   67    Male      Equatorial Guinea        Silvaberg         College        Unemployed              11275             Single
# 8   9    Melanie Walker   16   Other           Burkina Faso       Brandystad    Postgraduate           Retired              85495           Divorced
# 9  10      Carl Mathews   44    Male               Barbados      Roseborough      University     Self-Employed             192822             Single
#
#    children_count  smokes_per_day  drinks_per_week  age_started_smoking  age_started_drinking  attempts_to_quit_smoking  attempts_to_quit_drinking  \
# 0               3               5                4                   12                    29                         6                          2
# 1               4              11                3                   11                    24                         1                          6
# 2               5              13                4                   18                    27                         9                          9
# 3               3               7                4                   37                    14                         5                          7
# 4               0               8                2                   20                    35                         4                          7
# 5               0               6                4                   13                    35                         2                          3
# 6               1               9                5                   18                    23                         4                          9
# 7               2               8                3                   15                    33                         9                          1
# 8               1               8                6                   10                    36                         6                          5
# 9               2               7                2                   39                    16                         2                          2
#
#    has_health_issues mental_health_status exercise_frequency diet_quality  sleep_hours   bmi social_support therapy_history
# 0               True                 Good              Daily      Average          5.6  22.4            NaN         Current
# 1              False                 Poor             Weekly         Good          6.7  24.1       Moderate             NaN
# 2               True                 Good              Never         Good          6.2  22.2           Weak             NaN
# 3              False              Average              Daily         Good          7.2  25.5       Moderate         Current
# 4               True                 Poor             Weekly         Good          8.5  31.2           Weak            Past
# 5               True                 Good              Never      Average          6.4  29.3           Weak            Past
# 6              False                 Good             Weekly         Good          4.5  32.6       Moderate            Past
# 7               True              Average             Weekly         Good          3.6  24.6           Weak             NaN
# 8              False                 Good             Weekly         Good          4.6  24.6            NaN             NaN
# 9              False              Average             Weekly         Poor          4.5  26.0         Strong         Current

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'gender', 'country', 'city', 'education_level', 'employment_status', 'annual_income_usd', 'marital_status', 'children_count',
#        'smokes_per_day', 'drinks_per_week', 'age_started_smoking', 'age_started_drinking', 'attempts_to_quit_smoking', 'attempts_to_quit_drinking',
#        'has_health_issues', 'mental_health_status', 'exercise_frequency', 'diet_quality', 'sleep_hours', 'bmi', 'social_support', 'therapy_history'],
#       dtype='object')

# %%
df_copy = df.copy()
df_copy.set_index('id')
# Out:
#                   name  age  gender                      country           city education_level employment_status  annual_income_usd     marital_status  \
# id
# 1        Michael Bates   66   Other                        Yemen    Martinmouth       Secondary           Student              45595            Married
# 2       Brian Thompson   29    Male                 Saudi Arabia    Harperhaven         Primary     Self-Employed             145842             Single
# 3        Steven Little   75    Male                         Togo       Chanport    Postgraduate        Unemployed             162480             Single
# 4      Michael Mathews   35   Other                         Togo     North Cory      University        Unemployed              16023  In a relationship
# 5     Nicholas Sanchez   38  Female                      Morocco     Danielberg         College     Self-Employed              62933  In a relationship
# ...                ...  ...     ...                          ...            ...             ...               ...                ...                ...
# 2996     Mary Bartlett   29   Other                    Macedonia  Port Kimberly    Postgraduate          Employed             118269             Single
# 2997      Beth Sanchez   51    Male                 Saudi Arabia      Smithbury         College          Employed              35898            Widowed
# 2998       Megan Duffy   15    Male  Falkland Islands (Malvinas)      Clinebury         College           Retired             167501            Widowed
# 2999    Jeffery Lawson   38    Male                      Bermuda    Colleenport       Secondary           Retired             135893            Married
# 3000      Kathryn Gray   41   Other                      Jamaica     Turnertown             NaN          Employed             124049             Single
#
#       children_count  smokes_per_day  drinks_per_week  age_started_smoking  age_started_drinking  attempts_to_quit_smoking  attempts_to_quit_drinking  \
# id
# 1                  3               5                4                   12                    29                         6                          2
# 2                  4              11                3                   11                    24                         1                          6
# 3                  5              13                4                   18                    27                         9                          9
# 4                  3               7                4                   37                    14                         5                          7
# 5                  0               8                2                   20                    35                         4                          7
# ...              ...             ...              ...                  ...                   ...                       ...                        ...
# 2996               0               8                3                   33                    20                         9                          1
# 2997               2              11                5                   25                    23                         9                          2
# 2998               4              12                5                   27                    19                         1                          8
# 2999               2               9                6                   37                    23                         9                          3
# 3000               0              10                2                   21                    13                         3                          5
#
#       has_health_issues mental_health_status exercise_frequency diet_quality  sleep_hours   bmi social_support therapy_history
# id
# 1                  True                 Good              Daily      Average          5.6  22.4            NaN         Current
# 2                 False                 Poor             Weekly         Good          6.7  24.1       Moderate             NaN
# 3                  True                 Good              Never         Good          6.2  22.2           Weak             NaN
# 4                 False              Average              Daily         Good          7.2  25.5       Moderate         Current
# 5                  True                 Poor             Weekly         Good          8.5  31.2           Weak            Past
# ...                 ...                  ...                ...          ...          ...   ...            ...             ...
# 2996               True                 Poor              Never      Average          6.6  27.4       Moderate         Current
# 2997               True                 Poor             Rarely         Good          4.3  27.7       Moderate            Past
# 2998               True                 Poor             Rarely         Poor          6.6  23.5       Moderate            Past
# 2999              False                 Poor             Rarely         Poor          4.9  27.2            NaN         Current
# 3000              False                 Good              Daily      Average          5.2  19.6       Moderate            Past
#
# [3000 rows x 24 columns]
